# %% [markdown]
# # Week 11 - 25th October, 2023
#
# 1. Use the balanced/upsampled (if it was needed) CSV file used by you for kNN, build the SVM model with all possible kernels and compare their performance (i.e. accuracy using ROC-AUC score, precision, recall, F-score).  Submit the ipynb file.
#
# 2. For the same data set, you have done classification using 4 methods (Logistic Regression, Dec-Tree, kNN and SVM). Analyze and report which performed best. Explain the possible reasons of that model performing best.
#
# 3. Whether any ensembling technique performed better than the model reported in reply to above Q2. If so, report the results.
#
# Submit the explanation/analysis etc for Q2 and Q3 as a `.txt`/`.docx` file.

# %%
import pandas as pd

input_df = pd.read_csv('../classification-datasets/HeartEW.csv')

# Modifying the class column so that the values fall in the range of 0-1
input_df.Class = input_df.Class.apply(lambda x: x - 1)

input_df.head(5)
# Out:
#    Class  F1  F2  F3   F4   F5  F6  F7   F8  F9  F10  F11  F12  F13
# 0      0  34   1   1  118  182   0   2  174   0  0.0    1    0    3
# 1      1  53   1   4  140  203   1   2  155   1  3.1    3    0    7
# 2      1  61   1   1  134  234   0   0  145   0  2.6    2    2    3
# 3      0  68   1   3  118  277   0   0  151   0  1.0    1    1    7
# 4      1  54   1   4  122  286   0   2  116   1  3.2    2    2    3

# %%
import numpy as np

from sklearn import tree
from sklearn.metrics import accuracy_score

X_features = input_df.drop(['Class'], axis=1).columns
filtered_df = input_df[X_features]

import statsmodels.api as sm

X = sm.add_constant(filtered_df)
Y = input_df.Class

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size = 0.3, random_state = 100)
